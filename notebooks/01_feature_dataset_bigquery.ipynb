# %% [markdown]
# # Olist Customer Churn / Retention - Feature Dataset
#
# This notebook connects to BigQuery, pulls dbt models, and prepares a ML-ready dataset.

# %%
from google.cloud import bigquery
import pandas as pd

client = bigquery.Client()
query = '''
SELECT *
FROM `your_gcp_project_id.olist_dbt.dim_customers`
'''
df_customers = client.query(query).to_dataframe()
df_customers.head()
